# %% [markdown]
# # Trabalho mininet conceitos iniciais (C2115)
# ### Todos as imagens são os comandos utilizados e inseridos na ordem de realização das etapas.
#
# ##### Alunos: Maria Clara Ribeiro Ignácio e Samuel Almeida Ralise

# %% [markdown]
# ## 1
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 6
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## 7
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 8
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 9
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 10
# ##### Os dois *hosts* funcionando em terminais diferentes, com a interação registrada em dois terminais abertos em displays separados.
# ![image.png](attachment:image.png)
